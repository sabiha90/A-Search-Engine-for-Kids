# %%
import pandas as pd
df = pd.read_csv('whole_data.csv')

# %%
from io import StringIO

# %%
df = df.dropna()

# %%
col = ['text', 'class_name']

# %%
df = df[col]

# %%
df = df[pd.notnull(df['text'])]

# %%
df.columns = ['text','class_name']

# %%
import string
import nltk as nl
from nltk.corpus import stopwords 
import re
stop_words = set(stopwords.words('english')) 

df['text'] = df['text'].apply(lambda x: str(x).lower())
df['text'] = df['text'].apply(lambda x: x.translate(str.maketrans('','', string.punctuation)))
df['text'] = df['text'].apply(lambda x: x.translate(str.maketrans('','', string.digits)))
df['text'] = df['text'].apply(lambda x: re.sub("[^a-zA-Z0-9]+", " ", x))
df['text'] = df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
df['category_id'] = df['class_name'].factorize()[0]

# %%
category_id_df = df[['class_name','category_id']].drop_duplicates().sort_values('category_id')

# %%
category_to_id = dict(category_id_df.values)

# %%
id_to_category = dict(category_id_df[['category_id','class_name']].values)

# %%
df
# Out:
#                                                    text     class_name  \
# 0     hello everyone happy sunday welcome latest spi...  Entertainment
# 1                                            put laptop  Entertainment
# 2     looks like sun wanted introduce look meet sola...  Entertainment
# 3     dear olivei part work culture highly toxic get...  Entertainment
# 7                    unfortunately tis season sniffling  Entertainment
# 9     hello everyone moved new apartment last weeken...  Entertainment
# 13                                           previously  Entertainment
# 15         thanks reading feel feel check related humor  Entertainment
# 16    sending daughter college harder transition fig...  Entertainment
# 17    hey hottie looking good time little bit fire l...  Entertainment
# 21    holiday work life balance particularly tricky ...  Entertainment
# 24    acknowledgmentsthanks kitchenprojectcom peter ...  Entertainment
# 25    dear olivefor life stayed shell feels safe com...  Entertainment
# 26    excerpt part one big long memoir making lifede...  Entertainment
# 28    point tired talking issues moment also think m...  Entertainment
# 29                                  esther pearl watson  Entertainment
# 30                                           previously  Entertainment
# 31                                           previously  Entertainment
# 32                                          kasia babis  Entertainment
# 33                          httpwwwdieselsweetiescomics  Entertainment
# 34    stan lee died november th aged embodiment oldf...  Entertainment
# 35    meetcute staple romantic comedies adorable mom...  Entertainment
# 37                                                vreni  Entertainment
# 39    sean wisestan lee father marvel comics iconic ...  Entertainment
# 40    piece originally appeared new yorker daily shouts  Entertainment
# 42    printing exciting getting easier easier fun wi...  Entertainment
# 43                                           previously  Entertainment
# 44                                      brian mclachlan  Entertainment
# 45    raised thinking jewish safe much latelyby lisa...  Entertainment
# 46                                            matt bors  Entertainment
# ...                                                 ...            ...
# 1555  fight natural order things women men different...         Social
# 1556  eventful year hiphop lil wayne finally release...         Social
# 1557  hello welcome movie womani routineoriented org...         Social
# 1558  michael gushue cl bledsoea week ago bunch fede...         Social
# 1559  living coral life affirming nurturing shade ma...         Social
# 1560  offices king george queen caroline prince rich...         Social
# 1561  present first translation yet unpublished frag...         Social
# 1562  robots garnered suspicion since scientists fir...         Social
# 1563  recently hundred monkeys second annual burning...         Social
# 1564  throwback thursday piecemy whole life like eat...         Social
# 1565  know end times used read dead trees thing call...         Social
# 1566  sending daughter college harder transition fig...         Social
# 1567  today office making good promise create collab...         Social
# 1568  seminal song wham rap george michael prescient...         Social
# 1569  shawn mendes shawn mendesyou used nice guy lea...         Social
# 1570  define life growth activity change capacity re...         Social
# 1571  hey welcome everyday casualwear going allow he...         Social
# 1572  monday night man dave climbed bed pm crazy wee...         Social
# 1573  make cut year one beloved bejeweled bodyhairle...         Social
# 1574  little different average personsee pizza headm...         Social
# 1575  hey hottie looking good time little bit fire l...         Social
# 1576  patient notes sat december patient female lbs ...         Social
# 1577  hard gain monopoly elusive millennial consumer...         Social
# 1578  sunrise light streams across floorbed rise was...         Social
# 1579  communal bathrooms share family telephonebox s...         Social
# 1580  opened thinking going read wealthy mogul whose...         Social
# 1581  december largest historically recorded meteori...         Social
# 1582  deciding place eat damage relationship given u...         Social
# 1583  ebenezer scrooge visited spirits implore chang...         Social
# 1584  photo mcastromistockgetty images plusphoto mca...         Social
#
#       category_id
# 0               0
# 1               0
# 2               0
# 3               0
# 7               0
# 9               0
# 13              0
# 15              0
# 16              0
# 17              0
# 21              0
# 24              0
# 25              0
# 26              0
# 28              0
# 29              0
# 30              0
# 31              0
# 32              0
# 33              0
# 34              0
# 35              0
# 37              0
# 39              0
# 40              0
# 42              0
# 43              0
# 44              0
# 45              0
# 46              0
# ...           ...
# 1555            3
# 1556            3
# 1557            3
# 1558            3
# 1559            3
# 1560            3
# 1561            3
# 1562            3
# 1563            3
# 1564            3
# 1565            3
# 1566            3
# 1567            3
# 1568            3
# 1569            3
# 1570            3
# 1571            3
# 1572            3
# 1573            3
# 1574            3
# 1575            3
# 1576            3
# 1577            3
# 1578            3
# 1579            3
# 1580            3
# 1581            3
# 1582            3
# 1583            3
# 1584            3
#
# [1555 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(8,6))

# %%
df.groupby('class_name').text.count().plot.bar(ylim=0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=7, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')

# %%
features = tfidf.fit_transform(df.text).toarray()

# %%
labels = df.category_id

# %%
features.shape
# Out:
# (1555, 14223)

# %%
from sklearn.feature_selection import chi2
import numpy as np

# %%
N=2
for Tag_Class, category_id in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("# '{}':".format(Tag_Class))
    print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
    print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# # 'Academics':
#   . Most correlated unigrams:
# . quantum
# . code
#   . Most correlated bigrams:
# . data structures
# . data structure
# # 'Entertainment':
#   . Most correlated unigrams:
# . characters
# . film
#   . Most correlated bigrams:
# . video game
# . social media
# # 'Life':
#   . Most correlated unigrams:
# . football
# . food
#   . Most correlated bigrams:
# . football team
# . minutes later
# # 'Social':
#   . Most correlated unigrams:
# . emissions
# . climate
#   . Most correlated bigrams:
# . fossil fuel
# . climate change

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['category_id'],test_size=0.3, random_state = 0)
count_vect = CountVectorizer()
X_train
# Out:
# 16      sending daughter college harder transition fig...
# 853     cannon cravens rides first bull ever professio...
# 1451    zerotolerance immigration policy trump adminis...
# 466     someone slightest bit math without doublecheck...
# 572     antonio regaladoit could anyone easy junjiu huang
# 658                                          sean captain
# 578     many people cooking following recipes series i...
# 748     like capture moments grab air taking pictures ...
# 1478    faintly remember feels believe god feeling lov...
# 569     around time started journey research replicati...
# 719     million people attending american college univ...
# 716     computer science graduate tutor teacher worked...
# 1550    hi hi hi mandarin duck herei seen news lot lat...
# 1134    lila thulinyou seen podium human brain mirror ...
# 728     lessons followed fairly basic format tweaking ...
# 1417    new yorkers grumbled way polls year facing lon...
# 843     hated every fiber beingin beginning merely sym...
# 468     great finish part qubit quantum bit core build...
# 691     part series women color academydear doctoral w...
# 670     marco rubiothere path stable prosperous life a...
# 487     photo steven erricogetty imagesphoto steven er...
# 1275    almost kg co every year released mainly stays ...
# 216     mutant year zero search eden interesting mix r...
# 540     going make bold claim every developer aspiring...
# 737     brian fagansome kilometers north mexico city b...
# 510     project natasha sun trevor jones rob misasi lu...
# 673     education supposed prepare future traditionall...
# 678     december answer life problems deeply rooted ed...
# 1166    address city council city leaders mayor rahm e...
# 542     learning code hard software engineering field ...
#                               ...
# 875     story originally published naturesome scientis...
# 471     yes cannot know sure win odds winning high eve...
# 1484    world look like million migrants refugees repr...
# 779     words anonymous ivy league admissions officer ...
# 1002    usually two types travelling souls tourists wa...
# 135     second post looking one movies afi top list di...
# 801     decide husband said crouched front tv watch th...
# 91      looking good market conditions reflection nove...
# 870     stefanos geroulanos todd meyerscentenary celeb...
# 560     original caption tibetan plateau sits rain sha...
# 874     given night would wake hear sound floor made s...
# 195     johnskyrim game decadeby john zamborskythe eld...
# 107     strongly suspect one big reasons majority peop...
# 574     concept regeneration intrigued society decades...
# 1539    michael gushue cl bledsoepeople used something...
# 729     know problem kids days read veteran english te...
# 337     streamlabs introduced another way streamers ma...
# 1449    matt taibbi wrong elitism asked washington pos...
# 624     martin tisneit summer rachel broke sitting bar...
# 1525    namaste cousinmother informed student loan har...
# 1120    perfect world kevin durant would superman team...
# 623     daniel grosson late spring evening south stree...
# 299     eventful year hiphop lil wayne finally release...
# 1059                                      esther landhuis
# 1412    word year idiotit actually googled word us rig...
# 787     nikolai vavilov man mission end hunger russian...
# 860     story ps kenya health communication marketing ...
# 1244    article originally appeared tomdispatchcom rec...
# 583     lilara laughter fades awed silence autocab dri...
# 708     meateater justify tried going vegetarian let a...
# Name: text, Length: 1088, dtype: object

# %%
X_train_counts = count_vect.fit_transform(X_train.values.astype('U')).toarray()
X_train_counts.shape
# Out:
# (1088, 62726)

# %%
tfidf_transformer = TfidfTransformer()

# %%
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
model = MultinomialNB()

# %%
model.fit(X_train_tfidf, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_pred = model.predict(count_vect.transform(X_test.values.astype('U')).toarray())

# %%
from sklearn.metrics import accuracy_score,f1_score, precision_score, recall_score
print(accuracy_score(y_pred,y_test))
print(f1_score(y_pred,y_test,average='weighted'))
print(precision_score(y_pred,y_test,average='weighted'))
print(recall_score(y_pred,y_test,average='weighted'))
# Out:
# 0.655246252677
# 0.671651122131
# 0.719674152056
# 0.655246252677

# %%
from sklearn.cross_validation import KFold, cross_val_score
# Out:
# /home/girish/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
k_fold = KFold(len(X_train),n_folds=10, random_state=None, shuffle=False)
cross_val_score(model, X_train_tfidf, y_train, cv=k_fold, n_jobs=1)
# Out:
# array([ 0.66055046,  0.66972477,  0.66055046,  0.73394495,  0.69724771,
#         0.57798165,  0.71559633,  0.58715596,  0.67592593,  0.62962963])

# %%
pr = pd.read_csv('original_data_classified.csv',encoding = "ISO-8859-1")
# Out:
# /home/girish/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (33,52,54,58,60,63,68,77,86,89,92,95,101,118,136,155,160,184,193,198,205,210,216,252,389,405,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,430,431,432,433,434,435,436,437,439,440,441,442,443,444,445,446,447,448,449,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,471,472,473) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# 4521  https://medium.com/p/f51a45422c54?source=topic...  14323
# 4522  https://medium.com/p/2b1751186cea?source=topic...  21059
# 4523  https://medium.com/male-survivor/recommended-b...   2398
# 4524  https://medium.com/third-way/eleven-things-con...    990
# 4525  https://medium.com/p/9bb4738d02d5?source=topic...  21635
# 4526  https://medium.com/p/d58906e22275?source=topic...  18130
# 4527  https://medium.com/p/8d7b1c4c2239?source=topic...  21807
# 4528                                                NaN   4256
# 4529  https://medium.com/p/5ab6a0b3788b?source=topic...  13644
# 4530  https://medium.com/macuser-editorials/aol-time...   6814
#
# [4531 rows x 4 columns]

# %%
pr = pr[pr['class'] == 'Positive']

# %%
pr
# Out:
#                                           original_data     class  \
# 1     Adapted from a keynote address by Jennifer Ben...  Positive
# 3     âAddress should not determine accessâLast ...  Positive
# 4     Illustration: Rebecca ClarkeIllustration: Rebe...  Positive
# 5     Essay by Sarah Coefield.Itâs late August whe...  Positive
# 6     This entry is part of a project called Craigsl...  Positive
# 7     Scenario: You recently have been diagnosed wit...  Positive
# 8     The tipping point was 2008. I was content play...  Positive
# 9     It is nigh unto impossible for a sequel to be ...  Positive
# 11    By Katrina FoxIn August this year, a former Bu...  Positive
# 13    In the summer of 2010 I started working part-t...  Positive
# 14    Originally published on Proof Is In the Writin...  Positive
# 16    The recent Facebook congressional hearings fel...  Positive
# 17                                                  NaN  Positive
# 19    Pretend for a moment you were a young academic...  Positive
# 20                                                  NaN  Positive
# 21    To be beyond doubt is to be more, or perhaps l...  Positive
# 22    By John DiazThe scandal involving political co...  Positive
# 23    We seem to be living through an era defined by...  Positive
# 24    Plants simply arenât butch enough for men, p...  Positive
# 25    Self-righteousness + memes = sanctimonious cyb...  Positive
# 26    by Sean McTiernanOf all the movies weâre dis...  Positive
# 27    Ever since I was a kid, Chris Evans hasâââ...  Positive
# 28    When we look at our history, the Islamic conqu...  Positive
# 30    You can try to hide those memories in the nigh...  Positive
# 32    Recently Newsweek, the once-lauded news magazi...  Positive
# 33    By Caleb ScharfImagine that youâve lived you...  Positive
# 34    Photo: George J. SchroederPhoto: George J. Sch...  Positive
# 35    Josh BowsherClick for printable PDFListen to t...  Positive
# 36    Behind the music and romance, the underlying s...  Positive
# 37    Belgian photographer Anton Kusters has been wo...  Positive
# ...                                                 ...       ...
# 4485  In elementary school I won a mathematics award...  Positive
# 4486  Illustration: Rebecca ClarkeIllustration: Rebe...  Positive
# 4488  Letâs be transparent, I donât know why I a...  Positive
# 4489  Earlier this year, Tim and I had the opportuni...  Positive
# 4490  By David BressanâFor more than a century, pe...  Positive
# 4491  By Sarah WattsOur âbreastfeeding journeyâ ...  Positive
# 4493                                                NaN  Positive
# 4494  Much is already known about the origins of the...  Positive
# 4498  Illustration by: Alexandra BowmanIllustration ...  Positive
# 4499  Weâre halfway home on the NFL regular season...  Positive
# 4500  I have recently visited the Montessori PSA con...  Positive
# 4501  Imagine that I told you you had to build a mac...  Positive
# 4504  Each time we are faced with the compelling que...  Positive
# 4505  For nearly the entirety of 2018, the cryptocur...  Positive
# 4506  I run a newsletter on productivity and write a...  Positive
# 4509  Plastic is our collective addiction. Itâs in...  Positive
# 37    https://medium.com/p/2fd9bd0bcd30?source=topic...   7968
# ...                                                 ...    ...
# 4485  https://medium.com/p/2a8f75d803a?source=topic_...  13033
# 4486  https://medium.com/p/14c2346d449a?source=topic...   8570
# 4488  https://medium.com/p/5250ec0686e8?source=topic...  15079
# 4489  https://medium.com/p/c06b8aae8822?source=topic...  10928
# 4490  https://medium.com/p/19fa2e08a7f4?source=topic...  21296
# 4491  https://medium.com/qg-feminista/porque-v%C3%AD...   4896
# 4493  https://medium.com/the-awl/madonna-iggy-pop-th...   7303
# 4494  https://medium.com/p/59728b09753a?source=topic...  15879
# 4498                                                NaN  22392
# 4499  https://medium.com/p/a02dad6e43ca?source=topic...  19720
# 4500  https://medium.com/p/d297b018e849?source=topic...  13783
# 4501  https://medium.com/p/885c0aa507ad?source=topic...  11020
# 4504  https://medium.com/p/1f9760765b46?source=topic...  17118
# 4505  https://medium.com/p/4d860ffea792?source=topic...  10698
# 4506  https://medium.com/p/ec05cee1749a?source=topic...  17683
# 4509  https://medium.com/p/7508fe097c94?source=topic...   9677
# 4510  https://medium.com/p/dd4deb72448d?source=topic...  19226
# 4512  https://medium.com/p/288967f5baed?source=topic...  10352
# 4515  https://medium.com/p/f9d3b2d2d96d?source=topic...  13118
# 4517  https://medium.com/p/bc6efc0363e0?source=topic...   8507
# 4518  https://medium.com/p/adaa4d9a0749?source=topic...  15350
# 4519  https://medium.com/p/2dc02eec55dc?source=topic...  10423
# 4520  https://medium.com/p/7f8af8fc3471?source=topic...   7439
# 4521  https://medium.com/p/f51a45422c54?source=topic...  14323
# 4522  https://medium.com/p/2b1751186cea?source=topic...  21059
# 4523  https://medium.com/male-survivor/recommended-b...   2398
# 4525  https://medium.com/p/9bb4738d02d5?source=topic...  21635
# 4526  https://medium.com/p/d58906e22275?source=topic...  18130
# 4527  https://medium.com/p/8d7b1c4c2239?source=topic...  21807
# 4529  https://medium.com/p/5ab6a0b3788b?source=topic...  13644
#
# [3307 rows x 4 columns]

# %%
y_pred_new = model.predict(count_vect.transform(pr.original_data.values.astype('U')).toarray())
y_pred_new
len(y_pred_new)
# Out:
# 3307

# %%
pr['topic']=y_pred_new
# Out:
# /home/girish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pr.to_csv('topic_classified_test_data.csv',index=False)
#  df.to_csv(filename, index=False)

# %%
from sklearn.svm import LinearSVC

# %%
svc_model = LinearSVC()
svc_model.fit(X_train_tfidf, y_train)
y_pred_svc = svc_model.predict(count_vect.transform(X_test.values.astype('U')).toarray())
k_fold = KFold(len(X_train),n_folds=10, random_state=None, shuffle=True)
cross_val_score(svc_model, X_train_tfidf, y_train, cv=k_fold, n_jobs=1)
# Out:
# array([ 0.67889908,  0.67889908,  0.76146789,  0.69724771,  0.73394495,
#         0.69724771,  0.70642202,  0.64220183,  0.7037037 ,  0.7037037 ])

# %%
from sklearn.metrics import average_precision_score
print(accuracy_score(y_pred_svc,y_test))
print(f1_score(y_pred_svc,y_test,average='weighted'))
print(precision_score(y_pred_svc,y_test,average='weighted'))
print(recall_score(y_pred_svc,y_test,average='weighted'))
# Out:
# 0.640256959315
# 0.641051163297
# 0.67087489842
# 0.640256959315
