# %%
import pandas as pd

# %%
data = pd.read_csv('original_data_classified.csv', error_bad_lines=False, encoding = "ISO-8859-1");
# Out:
# /home/girish/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (33,52,54,58,60,63,68,77,86,89,92,95,101,118,136,155,160,184,193,198,205,210,216,252,389,405,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,430,431,432,433,434,435,436,437,439,440,441,442,443,444,445,446,447,448,449,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,471,472,473) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#                                           original_data     class  \
# 0     Three Reasons Why Gun Ownership Rates From Oth...  Negative
# 1     Adapted from a keynote address by Jennifer Ben...  Positive
# 2     By Maggie EthridgeIâm writing this to you if...  Negative
# 3     âAddress should not determine accessâLast ...  Positive
# 4     Illustration: Rebecca ClarkeIllustration: Rebe...  Positive
# 5     Essay by Sarah Coefield.Itâs late August whe...  Positive
# 6     This entry is part of a project called Craigsl...  Positive
# 7     Scenario: You recently have been diagnosed wit...  Positive
# 8     The tipping point was 2008. I was content play...  Positive
# 9     It is nigh unto impossible for a sequel to be ...  Positive
# 10    No one expects to become a statistic. But the ...  Negative
# 11    By Katrina FoxIn August this year, a former Bu...  Positive
# 12    Who doesnât love a good horror movie? OK, th...  Negative
# ...

# %%
data = data[['original_data','class','url','index']]

# %%
data
# Out:
#                                           original_data     class  \
# 0     Three Reasons Why Gun Ownership Rates From Oth...  Negative
# 1     Adapted from a keynote address by Jennifer Ben...  Positive
# 2     By Maggie EthridgeIâm writing this to you if...  Negative
# 3     âAddress should not determine accessâLast ...  Positive
# 4     Illustration: Rebecca ClarkeIllustration: Rebe...  Positive
# 5     Essay by Sarah Coefield.Itâs late August whe...  Positive
# 6     This entry is part of a project called Craigsl...  Positive
# 7     Scenario: You recently have been diagnosed wit...  Positive
# 8     The tipping point was 2008. I was content play...  Positive
# 9     It is nigh unto impossible for a sequel to be ...  Positive
# 10    No one expects to become a statistic. But the ...  Negative
# 11    By Katrina FoxIn August this year, a former Bu...  Positive
# 12    Who doesnât love a good horror movie? OK, th...  Negative
# ...

# %%
data_text = data[['original_data']]

# %%
data_text['index'] = data_text.index
# Out:
# /home/girish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_text
# Out:
#                                           original_data  index
# 0     Three Reasons Why Gun Ownership Rates From Oth...      0
# 1     Adapted from a keynote address by Jennifer Ben...      1
# 2     By Maggie EthridgeIâm writing this to you if...      2
# 3     âAddress should not determine accessâLast ...      3
# 4     Illustration: Rebecca ClarkeIllustration: Rebe...      4
# 5     Essay by Sarah Coefield.Itâs late August whe...      5
# 6     This entry is part of a project called Craigsl...      6
# 7     Scenario: You recently have been diagnosed wit...      7
# 8     The tipping point was 2008. I was content play...      8
# 9     It is nigh unto impossible for a sequel to be ...      9
# 10    No one expects to become a statistic. But the ...     10
# 11    By Katrina FoxIn August this year, a former Bu...     11
# 12    Who doesnât love a good horror movie? OK, th...     12
# 13    In the summer of 2010 I started working part-t...     13
# ...

# %%
documents = data_text

# %%
print(len(documents))
# Out:
# 4531

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem import SnowballStemmer
from nltk.stem.porter import *
from nltk.stem import PorterStemmer

import numpy as np
np.random.seed(2018)
import nltk
nltk.download('wordnet')
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package wordnet to /home/girish/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
doc_sample = documents[documents['index'] == 4310].values[0][0]
print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample))
# Out:
# original document:
# ...

# %%
documents = documents.dropna()
# processed_docs[:10]
# documents['original_data']

# %%
processed_docs = documents['original_data'].map(preprocess)
# processed_docs = documents.map(preprocess)

# %%
processed_docs
# Out:
# 0       [reason, ownership, rat, countri, donâ, matter...
# 1       [adapt, keynot, address, jennif, benka, presid...
# 2       [maggi, ethridgeiâ, write, believ, trumpâ, rem...
# 3       [address, determin, accessâ, week, sampson, co...
# 4       [illustr, rebecca, rebecca, clarkemorri, plain...
# 5       [essay, sarah, coefield, late, august, grandmo...
# 6       [entri, project, call, craigslist, confession,...
# 7       [scenario, recent, diagnos, health, condit, re...
# 8       [tip, point, content, play, game, larg, bedroo...
# 9       [nigh, unto, imposs, sequel, judg, merit, enti...
# 10      [expect, statist, sober, statist, entrepreneur...
# 11      [katrina, foxin, august, year, burger, king, r...
# 12      [doesnâ, love, good, horror, movi, donâ, artic...
# 13      [summer, start, work, time, promot, depart, yo...
# 14      [origin, publish, proof, write, april, work, h...
# 15      [note, link, mark, nsfw, whatâ, killer, crypto...
# ...

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 accept
# 1 access
# 2 achiev
# 3 acquir
# 4 add
# 5 advoc
# 6 agent
# 7 alarm
# 8 allow
# 9 america
# 10 american

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus[4310]
# Out:
# [(0, 1),
#  (30, 1),
#  (31, 1),
#  (71, 1),
#  (101, 3),
#  (105, 1),
#  (120, 1),
#  (128, 1),
#  (140, 1),
#  (155, 2),
#  (162, 1),
#  (177, 1),
#  (181, 1),
#  (194, 1),
#  (198, 1),
#  (201, 1),
#  (202, 3),
#  (206, 1),
#  (208, 3),
#  (209, 1),
#  (214, 2),
#  (218, 1),
#  (229, 1),
#  (245, 1),
#  (285, 1),
#  (301, 1),
#  (304, 1),
#  (308, 1),
#  (314, 1),
#  (319, 1),
#  (329, 1),
#  (345, 2),
#  (346, 1),
#  (349, 2),
#  (351, 1),
#  (356, 1),
#  (359, 2),
#  (364, 1),
#  (368, 3),
#  (371, 1),
#  (382, 1),
#  (385, 1),
#  (412, 4),
#  (438, 1),
#  (443, 2),
#  (450, 1),
#  (453, 1),
#  (458, 1),
#  (482, 1),
#  (487, 1),
#  (494, 1),
#  (509, 1),
#  (510, 1),
#  (535, 1),
#  (538, 1),
#  (592, 1),
#  (619, 1),
#  (621, 1),
#  (625, 1),
#  (658, 1),
#  (693, 1),
#  (698, 1),
#  (719, 1),
#  (720, 1),
#  (727, 1),
#  (728, 1),
#  (760, 1),
#  (788, 1),
#  (797, 4),
#  (800, 1),
#  (835, 1),
#  (838, 1),
#  (842, 1),
#  (843, 2),
#  (844, 1),
#  (846, 1),
#  (854, 1),
# ...

# %%
bow_doc_4310 = bow_corpus[4310]
for i in range(len(bow_doc_4310)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_4310[i][0], 
                                               dictionary[bow_doc_4310[i][0]], 
bow_doc_4310[i][1]))
# Out:
# Word 0 ("accept") appears 1 time.
# Word 30 ("believ") appears 1 time.
# Word 31 ("better") appears 1 time.
# Word 71 ("consid") appears 1 time.
# Word 101 ("donâ") appears 3 time.
# Word 105 ("dump") appears 1 time.
# Word 120 ("exactli") appears 1 time.
# Word 128 ("face") appears 1 time.
# Word 140 ("futur") appears 1 time.
# Word 155 ("half") appears 2 time.
# Word 162 ("high") appears 1 time.
# Word 177 ("inform") appears 1 time.
# Word 181 ("instead") appears 1 time.
# Word 194 ("kind") appears 1 time.
# Word 198 ("lead") appears 1 time.
# Word 201 ("letâ") appears 1 time.
# Word 202 ("life") appears 3 time.
# Word 206 ("look") appears 1 time.
# Word 208 ("make") appears 3 time.
# Word 209 ("manag") appears 1 time.
# Word 214 ("mean") appears 2 time.
# Word 218 ("member") appears 1 time.
# Word 229 ("neg") appears 1 time.
# Word 245 ("pass") appears 1 time.
# Word 285 ("read") appears 1 time.
# Word 301 ("respons") appears 1 time.
# Word 304 ("right") appears 1 time.
# ...

# %%
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.010983103479880799),
#  (1, 0.021628980388249001),
#  (2, 0.011336332217567975),
#  (3, 0.018305602914524797),
#  (4, 0.010583273844136836),
#  (5, 0.016624919551393551),
#  (6, 0.018109793797650247),
#  (7, 0.019735146421486993),
#  (8, 0.0073414001408525697),
#  (9, 0.024016416360520029),
#  (10, 0.0084348259410596382),
#  (11, 0.043077195290923256),
#  (12, 0.023973242265566675),
#  (13, 0.038176748102548959),
#  (14, 0.010779629054564763),
#  (15, 0.015141017104191318),
#  (16, 0.023017061125258923),
#  (17, 0.072153493319923767),
#  (18, 0.051717127834460593),
#  (19, 0.01292227478767473),
#  (20, 0.0067987601397815752),
#  (21, 0.044729076763094157),
#  (22, 0.030511128912008519),
#  (23, 0.014212515659669136),
#  (24, 0.023668530744767477),
#  (25, 0.031477337987281903),
#  (26, 0.010727740006169826),
#  (27, 0.031536300914073501),
#  (28, 0.011119892348352896),
#  (29, 0.012861310032817203),
#  (30, 0.0069066570693188459),
#  (31, 0.0058746459667670479),
# ...

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.006*"film" + 0.004*"say" + 0.004*"game" + 0.004*"look" + 0.004*"movi" + 0.004*"feel" + 0.003*"person" + 0.003*"start" + 0.003*"donâ" + 0.003*"world"
# Topic: 1
# Words: 0.006*"say" + 0.004*"youâ" + 0.003*"commun" + 0.003*"feel" + 0.003*"donâ" + 0.003*"help" + 0.003*"studi" + 0.003*"social" + 0.003*"differ" + 0.003*"life"
# Topic: 2
# Words: 0.006*"youâ" + 0.005*"donâ" + 0.004*"look" + 0.004*"product" + 0.003*"chang" + 0.003*"world" + 0.003*"help" + 0.003*"learn" + 0.003*"life" + 0.003*"tell"
# Topic: 3
# Words: 0.004*"say" + 0.003*"donâ" + 0.003*"number" + 0.003*"youâ" + 0.003*"tell" + 0.003*"read" + 0.003*"write" + 0.003*"live" + 0.003*"life" + 0.003*"look"
# Topic: 4
# Words: 0.005*"human" + 0.004*"world" + 0.003*"youâ" + 0.003*"person" + 0.003*"live" + 0.003*"creat" + 0.003*"mean" + 0.003*"feel" + 0.003*"learn" + 0.003*"look"
# Topic: 5
# ...

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.001*"sexual" + 0.001*"crime" + 0.001*"school" + 0.001*"data" + 0.001*"feel" + 0.001*"youâ" + 0.001*"game" + 0.001*"harass" + 0.001*"student" + 0.001*"love"
# Topic: 1 Word: 0.003*"previous" + 0.002*"women" + 0.002*"youâ" + 0.002*"school" + 0.002*"game" + 0.001*"film" + 0.001*"student" + 0.001*"feel" + 0.001*"learn" + 0.001*"theyâ"
# Topic: 2 Word: 0.002*"sexual" + 0.001*"women" + 0.001*"porn" + 0.001*"youâ" + 0.001*"crime" + 0.001*"say" + 0.001*"donâ" + 0.001*"assault" + 0.001*"team" + 0.001*"media"
# Topic: 3 Word: 0.002*"student" + 0.001*"alcohol" + 0.001*"facebook" + 0.001*"game" + 0.001*"youâ" + 0.001*"learn" + 0.001*"teacher" + 0.001*"human" + 0.001*"school" + 0.001*"twitter"
# Topic: 4 Word: 0.001*"youâ" + 0.001*"user" + 0.001*"feel" + 0.001*"say" + 0.001*"life" + 0.001*"write" + 0.001*"technolog" + 0.001*"product" + 0.001*"donâ" + 0.001*"compani"
# ...
